# %%
print('Olá')
# Out:
# Olá

# %%
print(Olá)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1482540774.py in <cell line: 0>()
# ----> 1 print(Olá)
#
# NameError: name 'Olá' is not defined

# %%
print(Ola)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-777366124.py in <cell line: 0>()
# ----> 1 print(Ola)
#
# NameError: name 'Ola' is not defined

# %%
Ola = 10
print(Ola)
# Out:
# 10

# %%
a = 1
print(a)
# Out:
# 1

# %%
b= 2

# %%
a + b
# Out:
# 3

# %% [markdown]
# # Inciando estudos de programação
#
# Primeira aula é de ambientação no Colab e no VS Studio CODE
