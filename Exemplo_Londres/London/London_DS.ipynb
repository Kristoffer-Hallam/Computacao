# %%
import pandas as pd

# %%
path_to_file = "drive/MyDrive/London/london_listings.csv"

# %%
df = pd.read_csv(path_to_file)
display(df)
# Out:
#              id                                               name    host_id  \
# 0         36299                Kew Gardens 3BR house in cul-de-sac     155938
# 1         15400                Bright Chelsea  Apartment. Chelsea!      60302
# 2         17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1      67564
# 3         36660                    You are GUARANTEED to love this     157884
# 4         17506  Boutique Chelsea/Fulham Double bed 5-star ensuite      67915
# ...         ...                                                ...        ...
# 66635  25243555                    Ivy | Thames View | Pro-Managed   10961046
# 66636  25798888                    Light room - Luma Concept Hotel  174135687
# 66637  25852757                              Two Bedroom Apartment  182547447
# 66638  25855468                                   Luma Double room  174135687
# 66639  25855538                                     Luma Twin Room  174135687
#
# ...
